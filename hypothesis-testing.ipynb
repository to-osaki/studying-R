# %%
# 仮説検定

# %%
# normal distribution
dnorm(0.1, mean = 0, sd = 1) # 確率密度
pnorm(1, mean = 0, sd = 1) # p値
qnorm(0.5, mean = 0, sd = 1) # パーセント点
# binom = 2項分布、chisq = Χ二乗分布、f = F分布、t = t分布、unif = 一様分布
# Out:
# [1] 0.3969525
# [1] 0.8413447
# [1] 0

# %%
values = rnorm(1000, mean = 0, sd = 1)
hist(values, freq = F, breaks = "scott", xlim = c(-5, 5))
curve(dnorm(x), add = T)
# Out:
# Plot with title "Histogram of values"

# %%
p = 0.3
hist(rbinom(1000, size = 10, prob = p), freq = F, xlim = c(0, 10))
# Out:
# Plot with title "Histogram of rbinom(1000, size = 10, prob = p)"

# %%
curve(dchisq(x, 1), xlim = c(0, 20))
curve(dchisq(x, 2), xlim = c(0, 20))
curve(dchisq(x, 3), xlim = c(0, 20), add =)
# Out:
# plot without title

# %%
x = c(45, 25, 22, 8)
y = c(40, 30, 20, 10)
d = (x - y)
X2 = sum(d * d / y)
1 - pchisq(X2, df = length(x) - 1)
# Out:
# [1] 0.5603881

# %%
chisq.test(x, p = y / 100)
# Out:
# 	Chi-squared test for given probabilities
#
# data:  x
# X-squared = 2.0583, df = 3, p-value = 0.5604
